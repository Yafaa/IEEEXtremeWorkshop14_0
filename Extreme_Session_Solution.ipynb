# %% [markdown]
# # **Note**

# %% [markdown]
# # **Extreme Session Solution**

# %%
#Time of a program
import time
# starting time
start = time.time()

for i in range(100000000000000000000000000000000000000):
    #print(i)
    i=i*20000000
# end time
end = time.time()

# total time taken
print(f"Runtime of the program is {end - start}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-130-41c2a7aec815> in <module>()
#       4 start = time.time()
#       5
# ----> 6 for i in range(100000000000000000000000000000000000000):
#       7     #print(i)
#       8     i=i*20000000
#
# KeyboardInterrupt:

# %% [markdown]
# # **Problem 1**

# %%
def matchingStrings(strings, queries):
    words = dict()
    ans = []
    for w in strings:
        if w in words:
            words[w] += 1
        else:
            words[w] = 1
    for q in queries:
        if q in words:
            ans.append(words[q])
        else:
            ans.append(0)
    return ans

# %%
 matchingStrings(["ab","ab","abd"],["ab","abd","abc"])
# Out:
# [2, 1, 0]

# %%
 matchingStrings(["a","aa","bbbb"],["a","jj","kk"])
# Out:
# [1, 0, 0]

# %% [markdown]
# # **Problem 2**

# %%
def digits(n):
  it=str(n)
  s=0   
  for i in it:
    if int(i)!=0 and  n % int(i) ==0:
      s+=1
  print(s)

# %%
digits(111)
# Out:
# 3

# %%
digits(24)
# Out:
# 2

# %% [markdown]
# # **Problem 3**

# %%
# Complete the sockMerchant function below.
def sockMerchant(ar):
  ar.sort()
  p=0
  i=1
  while(i<len(ar)):
      if ar[i]==ar[i-1]:
          p=p+1
          i=i+2
      else:
          i=i+1  
  print(p)

# %%
ar1=[10,20,20,10,10,30,50,10,20]
ar2=[1,1,3,1,2,1,3,3,3,3]
sockMerchant(ar1)
sockMerchant(ar2)
# Out:
# 3
# 4

# %% [markdown]
# # **Problem 4**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Dynamic Solution
def KS(n,C):

# %%
def knapSack(W, wt, val, n): 
    K = [[0 for x in range(W + 1)] for x in range(n + 1)] 
  
    # Build table K[][] in bottom up manner 
    for i in range(n + 1): 
        for w in range(W + 1): 
            if i == 0 or w == 0: 
                K[i][w] = 0
            elif wt[i-1] <= w: 
                K[i][w] = max(val[i-1] + K[i-1][w-wt[i-1]],  K[i-1][w]) 
            else: 
                K[i][w] = K[i-1][w] 
  
    return K[n][W] 
  
# Driver program to test above function 
val = [60, 100, 120] 
wt = [10, 20, 30] 
W = 50
n = len(val) 
print(knapSack(W, wt, val, n))
# Out:
# 220

# %% [markdown]
# # **Recursive Algorithms**
# Recursion is one of the most ubiquitous algorithmic concepts. Simply, an
# algorithm is recursive if it calls itself.

# %%
def somme(n):
  print(n)
  return somme(n+1)

# %%
#somme(3)

# %%
def fact( n):
  if (n <= 1) :
        return 1
  else:    
        return n*fact(n-1)

# %%
fact(6)
# Out:
# 720

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Dynamic Programming Algorithms**
# During this process, the number of subproblems may become very large,
# and some algorithms solve the same subproblem repeatedly, needlessly
# increasing the running time. Dynamic programming organizes computations
# to avoid recomputing values that you already know, which can often
# save a great deal of time.

# %%
def factD(n):
  r=[]
  r.append(1)
  for i in range(1,n+1):
    s=i*r[i-1]
    r.append(s)
  return r[n]

# %%
fact(6)
# Out:
# 720

# %%
#start
start = time.time()
fact(600) #10
# end time
end = time.time()

# total time taken
print(f"Runtime of the program is {end - start}")
# Out:
# Runtime of the program is 0.0021877288818359375

# %%
#start
start = time.time()
factD(600) #10
# end time
end = time.time()

# total time taken
print(f"Runtime of the program is {end - start}")
# Out:
# Runtime of the program is 0.0009970664978027344

# %% [markdown]
# ![image.png](data:image/png;base64,...)
